# %% [markdown]
# <a href="https://colab.research.google.com/github/Nivetha-47/Machine_Learning/blob/main/Image_Classification_Using_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input,LSTM,Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical #to_categorical-->One-Hot Encoding

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x_train=x_train.reshape((60000,28,28)).astype('float32')/255
x_test=x_test.reshape((10000,28,28)).astype('float32')/255

# %%
y_train=to_categorical(y_train)
y_test=to_categorical(y_test)

# %%
inputs=Input(shape=(28,28))
rnn_layer=LSTM(128)(inputs)
outputs=Dense(10,activation='softmax')(rnn_layer)
model=Model(inputs=inputs,outputs=outputs)

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=5,batch_size=64,validation_split=0.2)
# Out:
# Epoch 1/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.6920 - loss: 0.9048 - val_accuracy: 0.9425 - val_loss: 0.1866
# Epoch 2/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9514 - loss: 0.1616 - val_accuracy: 0.9651 - val_loss: 0.1137
# Epoch 3/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9709 - loss: 0.0960 - val_accuracy: 0.9710 - val_loss: 0.0967
# Epoch 4/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9780 - loss: 0.0739 - val_accuracy: 0.9786 - val_loss: 0.0720
# Epoch 5/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9818 - loss: 0.0581 - val_accuracy: 0.9763 - val_loss: 0.0796

# %%
test_loss,test_acc =model.evaluate(x_test,y_test)  # evalution of test and train data
print("test accuracy:",test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9683 - loss: 0.1045
# test accuracy: 0.9739000201225281
