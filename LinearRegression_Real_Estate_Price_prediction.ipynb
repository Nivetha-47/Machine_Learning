# %% [markdown]
# <a href="https://colab.research.google.com/github/Nivetha-47/Machine_Learning/blob/main/LinearRegression_Real_Estate_Price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/real_estate_price_size.csv")
df
# Out:
#          price     size
# 0   234314.144   643.09
# 1   228581.528   656.22
# 2   281626.336   487.29
# 3   401255.608  1504.75
# 4   458674.256  1275.46
# ..         ...      ...
# 95  252460.400   549.80
# 96  310522.592  1037.44
# 97  383635.568  1504.75
# 98  225145.248   648.29
# 99  274922.856   705.29
#
# [100 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# price    0
# size     0
# dtype: int64

# %%
x=df[['size']]
y=df[['price']]
plt.scatter(x,y,facecolor='blue',color='black')
plt.xlabel('size')
plt.ylabel('price')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.intercept_)
print(lr.coef_)
# Out:
# [104769.58663143]
# [[216.2530156]]

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
r=r2_score(y_test,y_pred)
r
# Out:
# 0.6921167959760717

# %%
lr.predict([[1200],[789]])
# Out:
# array([[364273.20534751],
#        [275393.21593726]])

# %%
plt.scatter(x_train,y_train,color='grey')
plt.plot(x_test,y_pred,color='black')

# %% [markdown]
# TO FIND THE ERROR LINE

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mean_squared_error(y_test,y_pred))
print('MAE: ' ,mae)
print('MSE: ' ,mae)
print('RMSE: ' ,rmse)
# Out:
# MAE:  38758.039080151866
# MSE:  38758.039080151866
# RMSE:  47093.86849079664
